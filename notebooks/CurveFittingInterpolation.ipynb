# %%
import numpy as np
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
cd ..
# Out:
# /home/roger/Code/Comp_Physics

# %%
from scripts.interpolation import *

# %%
def correctFunction(x):
    return 15 + 2 * x - 0.5 * x**2 - 0.35 * x**3

# %%
a0 = np.array([15, 2, -0.5, -0.35])

# %%
npoints = 21

# %%
x_list = np.linspace(-5, 5, npoints)
data0 = np.array([x_list, correctFunction(x_list)])

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.plot(data0[0], data0[1])
plt.scatter(x_list, polynomialModel(x_list, a0))

# %%
data = np.array([data0[0] + 0.25 * (2*np.random.rand(npoints)-1), data0[1] + 5.0 * (2*np.random.rand(npoints)-1) ])

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(data[0], data[1])
plt.plot(x_list, polynomialModel(x_list, a0))

# %%
iterations = 100000
h = 0.00001
a = 2*np.random.rand(4)-1

# %%
a
# Out:
# array([ 0.72929526,  0.41473014, -0.38855323, -0.6547301 ])

# %%
for i in range(iterations):
    a = a - h*errorFitGradient(polynomialModel, a, data)

# %%
plt.xlabel('x')
plt.ylabel('y')

x_list = np.linspace(-5,5,npoints)
plt.plot(x_list, polynomialModel(x_list, a), 'black')
plt.plot(x_list, polynomialModel(x_list, a0), 'orange' )
plt.scatter(data[0], data[1])

# %%
print(errorFit(polynomialModel, a, data))
print(errorFit(polynomialModel, a0, data))
# Out:
# 223.7014330653234
# 263.3515910090952
